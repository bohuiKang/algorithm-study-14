# %%
#lst = list(map(int, input().split()))
#lst.sort()
#print(lst[1])

#내장함수 없이
a, b, c = map(int, input().split())
if a >= b:
    if a >= c:
        if b >= c:
            print(b)
        else:
            print(c)
    else:
        print(a)
else:
    if b >= c:
        if c >= a:
            print(c)
        else:
            print(a)
    else:
        print(b)
